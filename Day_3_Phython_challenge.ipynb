# %% [markdown]
# ###Day 39 – Tuple, Immutable vs Mutable, List Creation
# ###Project Title: Retail Inventory Manager
# Scenario: You are managing an inventory system for a retail shop. Certain product categories are fixed, but the actual products can be added or removed by the staff. Tasks: Create a tuple with fixed product categories like Electronics, Stationery, and Clothing. Create a list of products that can be updated dynamically. Ask the user to enter a new product and add it to the list. Ask the user to input the index of a product to remove it from the list. Display the final list of products and the product categories.

# %%
# 1. Tuple with fixed product categories
product_categories = ("Electronics", "Stationery", "Clothing")

# %%
# 2. List of products (dynamic)
products = ["Laptop", "Pen", "T-shirt"]

# %%
# 3. Ask user to enter a new product
new_product = input("Enter a new product to add: ")
products.append(new_product)
print("Product added!")
# Out:
# Enter a new product to add: Pen
# Product added!

# %%
# 4. Ask user to input the index of a product to remove
print("\nCurrent product list with indexes:")
for i, item in enumerate(products):
    print(i, ":", item)
    remove_index = int(input("Enter the index of the product to remove: "))
# Out:
# Current product list with indexes:
# 0 : Laptop
# Enter the index of the product to remove: 1
# 1 : Pen
# Enter the index of the product to remove: 0
# 2 : T-shirt
# Enter the index of the product to remove: 0
# 3 : Pen
# Enter the index of the product to remove: 0

# %%
# Validate index
if 0 <= remove_index < len(products):
    removed_item = products.pop(remove_index)
    print(f"{removed_item} removed from the inventory.")
else:
    print("Invalid index! No item removed.")
# Out:
# Laptop removed from the inventory.

# %%
# 5. Display final list and categories
print("\nFinal Product List:", products)
print("Product Categories:", product_categories)
# Out:
# Final Product List: ['Pen', 'T-shirt', 'Pen']
# Product Categories: ('Electronics', 'Stationery', 'Clothing')
